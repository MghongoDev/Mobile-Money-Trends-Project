# %%
import pandas as pd
import requests

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/share-adults-bank-account-financial-institution-mobile-money.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Fetch the metadata
metadata = requests.get("https://ourworldindata.org/grapher/share-adults-bank-account-financial-institution-mobile-money.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

# %%
df.info()
df.shape
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   entity                              264 non-null    str
#  1   code                                235 non-null    str
#  2   year                                264 non-null    int64
#  3   both_accounts                       264 non-null    float64
#  4   only_financial_institution_account  264 non-null    float64
#  5   only_mobile_money_account           264 non-null    float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 12.5 KB
#         entity code  year  both_accounts  only_financial_institution_account  \
# 0  Afghanistan  AFG  2014       0.304404                            9.656597
# 1  Afghanistan  AFG  2017       0.567588                           13.979497
# ...
